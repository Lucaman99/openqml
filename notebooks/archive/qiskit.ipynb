,
        0.08838835-0.03661165j, -0.08838835-0.21338835j,
        0.21338835-0.08838835j,  0.03661165+0.08838835j,
        0.39016504+0.08838835j, -0.03661165+0.16161165j,
        0.08838835-0.03661165j, -0.08838835-0.21338835j,
       -0.08838835+0.14016504j,  0.33838835+0.21338835j,
       -0.21338835+0.33838835j, -0.14016504-0.08838835j,
        0.21338835-0.08838835j,  0.03661165+0.08838835j]), np.array([ 0.08838835-0.39016504j,  0.16161165+0.03661165j,
       -0.08838835-0.21338835j,  0.08838835-0.03661165j,
        0.03661165+0.08838835j,  0.21338835-0.08838835j,
       -0.03661165+0.16161165j,  0.39016504+0.08838835j,
       -0.08838835-0.21338835j,  0.08838835-0.03661165j,
        0.33838835+0.21338835j, -0.08838835+0.14016504j,
       -0.14016504-0.08838835j, -0.21338835+0.33838835j,
        0.03661165+0.08838835j,  0.21338835-0.08838835j]), np.array([ 0.08838835-0.03661165j, -0.08838835-0.21338835j,
        0.16161165+0.03661165j,  0.08838835-0.39016504j,
        0.39016504+0.08838835j, -0.03661165+0.16161165j,
        0.21338835-0.08838835j,  0.03661165+0.08838835j,
       -0.08838835+0.14016504j,  0.33838835+0.21338835j,
        0.08838835-0.03661165j, -0.08838835-0.21338835j,
        0.21338835-0.08838835j,  0.03661165+0.08838835j,
       -0.21338835+0.33838835j, -0.14016504-0.08838835j]), np.array([-0.08838835-0.21338835j,  0.08838835-0.03661165j,
        0.08838835-0.39016504j,  0.16161165+0.03661165j,
       -0.03661165+0.16161165j,  0.39016504+0.08838835j,
        0.03661165+0.08838835j,  0.21338835-0.08838835j,
        0.33838835+0.21338835j, -0.08838835+0.14016504j,
       -0.08838835-0.21338835j,  0.08838835-0.03661165j,
        0.03661165+0.08838835j,  0.21338835-0.08838835j,
       -0.14016504-0.08838835j, -0.21338835+0.33838835j])]

qubits = [cirq.GridQubit(0, i) for i in range(0, 4)]


def create_circuit_layer(qubits, params1, params2, params3, input_string, a):
    
    for i in range(0, len(input_string)):
        if (input_string[i] == 1):
            yield cirq.X.on(qubits[i])
    
    for i in range(0, 4):
        
        yield cirq.ZPowGate(exponent=params2[i]).on(qubits[i])
        yield cirq.XPowGate(exponent=params1[i]).on(qubits[i])
        yield cirq.YPowGate(exponent=params3[i]).on(qubits[i])
        
        yield cirq.CX.on(qubits[i%4], qubits[(i+a)%4])
        
        yield cirq.ZPowGate(exponent=params2[i]).on(qubits[i])
        yield cirq.XPowGate(exponent=params1[i]).on(qubits[i])
        yield cirq.YPowGate(exponent=params3[i]).on(qubits[i])
        
strings = [[int(i) for i in list(str(bin(j))[2:].zfill(4))] for j in range(0, 16)]

def cost_function(params):
    
    total_cost = 0
    
    for i in strings:
        
        circuit = cirq.Circuit()
        circuit.append(create_circuit_layer(qubits, params[0:4], params[4:8], params[8:12], i, 1))
        circuit.append(create_circuit_layer(qubits, params[0:4], params[4:8], params[8:12], i, 2))
        simulator = cirq.Simulator()
        results = simulator.simulate(circuit).final_state
        # Calculates the cost
        
        initial_vec = [0 for i in range(0, 16)]
        initial_vec[strings.index(i)] = 1
        
        target_vector = np.matmul(U, initial_vec)
        total_cost += 1 - (np.dot(np.conj(target_vector), results) * np.dot(np.conj(results), target_vector))
    
    print(total_cost / 16)
    return total_cost / 16

par = [random.randint(0, 650)/100 for i in range(0, 12)]
out = minimize(cost_function, x0=par, method="COBYLA", options={'maxiter':1000})
print(out)
# Out:
# (0.9344347845287404+0j)
# (0.9451040331055464+0j)
# (0.917883279060867+0j)
# (0.9396915984182226+0j)
# (0.9351279411256861+0j)
# (0.9316972106759408+0j)
# (0.9408466410799813+0j)
# (0.9126639808938832+0j)
# (0.9377968783052126+0j)
# (0.9579902959783227+0j)
# (0.9498190892168032+0j)
# (0.9380308982815577+0j)
# (0.9213241304457127+0j)
# (0.9391155278803329+0j)
# (0.8416304887131663+0j)
# (0.8415278800915046+0j)
# (0.8415157602473213+0j)
# (0.8415514367374045+0j)
# (0.841615308451128+0j)
# (0.8415824003202256+0j)
# (0.8414856272048687+0j)
# (0.8414712351489146+0j)
# (0.8414006118670934+0j)
# (0.8412620809922565+0j)
# (0.8412542761297755+0j)
# (0.8413165432618898+0j)
# (0.8412508080213105+0j)
# (0.8412288302572035+0j)
# (0.8412565908494513+0j)
# (0.8412213302571805+0j)
# (0.8411418649090265+0j)
# (0.8411726906678106+0j)
# (0.841108211846014+0j)
# (0.8411834959433904+0j)
# (0.8410891272193579+0j)
# (0.8410948893872237+0j)
# (0.8411364591649155+0j)
# (0.8410830450674639+0j)
# (0.8410728171355268+0j)
# (0.8410321309277025+0j)
# (0.8410320634744696+0j)
# (0.8410149605660314+0j)
# (0.8410181663269146+0j)
# (0.841044269659297+0j)
# (0.84100560913271+0j)
# (0.8409508671913353+0j)
# (0.840902949661192+0j)
# (0.840876263125786+0j)
# (0.8408582889685433+0j)
# (0.8408251219989309+0j)
# (0.8408519454282538+0j)
# (0.8408266098566248+0j)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-3cb6cfeb74c4> in <module>
#     165
#     166 par = [random.randint(0, 650)/100 for i in range(0, 12)]
# --> 167 out = minimize(cost_function, x0=par, method="COBYLA", options={'maxiter':1000})
#     168 print(out)
#
# /usr/local/lib/python3.7/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     613                              **options)
#     614     elif meth == 'cobyla':
# --> 615         return _minimize_cobyla(fun, x0, args, constraints, **options)
#     616     elif meth == 'slsqp':
#     617         return _minimize_slsqp(fun, x0, args, jac, bounds,
#
# /usr/local/lib/python3.7/site-packages/scipy/optimize/cobyla.py in _minimize_cobyla(fun, x0, args, constraints, rhobeg, tol, maxiter, disp, catol, **unknown_options)
#     250     xopt, info = _cobyla.minimize(calcfc, m=m, x=np.copy(x0), rhobeg=rhobeg,
#     251                                   rhoend=rhoend, iprint=iprint, maxfun=maxfun,
# --> 252                                   dinfo=info)
#     253
#     254     if info[3] > catol:
#
# /usr/local/lib/python3.7/site-packages/scipy/optimize/cobyla.py in calcfc(x, con)
#     240
#     241     def calcfc(x, con):
# --> 242         f = fun(x, *args)
#     243         i = 0
#     244         for size, c in izip(cons_lengths, constraints):
#
# <ipython-input-26-3cb6cfeb74c4> in cost_function(params)
#     149
#     150         circuit = cirq.Circuit()
# --> 151         circuit.append(create_circuit_layer(qubits, params[0:4], params[4:8], params[8:12], i, 1))
#     152         circuit.append(create_circuit_layer(qubits, params[0:4], params[4:8], params[8:12], i, 2))
#     153         simulator = cirq.Simulator()
#
# /usr/local/lib/python3.7/site-packages/cirq/circuits/circuit.py in append(self, moment_or_operation_tree, strategy)
#    1300             strategy: How to pick/create the moment to put operations into.
#    1301         """
# -> 1302         self.insert(len(self._moments), moment_or_operation_tree, strategy)
#    1303
#    1304     def clear_operations_touching(self, qubits: Iterable['cirq.Qid'],
#
# /usr/local/lib/python3.7/site-packages/cirq/circuits/circuit.py in insert(self, index, moment_or_operation_tree, strategy)
#     985                 ops.transform_op_tree(moment_or_operation_tree,
#     986                                       self._device.decompose_operation,
# --> 987                                       preserve_moments=True),))
#     988
#     989         for moment_or_op in moments_and_operations:
#
# /usr/local/lib/python3.7/site-packages/cirq/ops/op_tree.py in flatten_to_ops_or_moments(root)
#     125         yield root
#     126     elif isinstance(root, Iterable) and not isinstance(root, str):
# --> 127         for subtree in root:
#     128             yield from flatten_to_ops_or_moments(subtree)
#     129     else:
#
# /usr/local/lib/python3.7/site-packages/cirq/ops/op_tree.py in <genexpr>(.0)
#     162     if isinstance(root, Iterable) and not isinstance(root, str):
#     163         return iter_transformation(
# --> 164             transform_op_tree(subtree,
#     165                               op_transformation,
#     166                               iter_transformation,
#
# <ipython-input-26-3cb6cfeb74c4> in create_circuit_layer(qubits, params1, params2, params3, input_string, a)
#     132         yield cirq.ZPowGate(exponent=params2[i]).on(qubits[i])
#     133         yield cirq.XPowGate(exponent=params1[i]).on(qubits[i])
# --> 134         yield cirq.YPowGate(exponent=params3[i]).on(qubits[i])
#     135
#     136         yield cirq.CX.on(qubits[i%4], qubits[(i+a)%4])
#
# /usr/local/lib/python3.7/site-packages/cirq/ops/raw_types.py in on(self, *qubits)
#     198         # Avoids circular import.
#     199         from cirq.ops import gate_operation
# --> 200         return gate_operation.GateOperation(self, list(qubits))
#     201
#     202     def wrap_in_linear_combination(self,
#
# /usr/local/lib/python3.7/site-packages/cirq/ops/gate_operation.py in __init__(self, gate, qubits)
#      39             qubits: The qubits to operate on.
#      40         """
# ---> 41         gate.validate_args(qubits)
#      42         self._gate = gate
#      43         self._qubits = tuple(qubits)
#
# /usr/local/lib/python3.7/site-packages/cirq/ops/raw_types.py in validate_args(self, qubits)
#     188             ValueError: The gate can't be applied to the qubits.
#     189         """
# --> 190         _validate_qid_shape(self, qubits)
#     191
#     192     def on(self, *qubits: Qid) -> 'Operation':
#
# /usr/local/lib/python3.7/site-packages/cirq/ops/raw_types.py in _validate_qid_shape(val, qubits)
#     515                              val, qid_shape,
#     516                              tuple(qid.dimension for qid in qubits), qubits))
# --> 517     if len(set(qubits)) != len(qubits):
#     518         raise ValueError('Duplicate qids for <{!r}>. '
#     519                          'Expected unique qids but got <{!r}>.'.format(
#
# /usr/local/lib/python3.7/site-packages/cirq/ops/raw_types.py in __hash__(self)
#      87
#      88     def __hash__(self):
# ---> 89         return hash((Qid, self._comparison_key()))
#      90
#      91     def __eq__(self, other):
#
# /usr/local/lib/python3.7/site-packages/cirq/devices/grid_qubit.py in _comparison_key(self)
#      43
#      44     def _comparison_key(self):
# ---> 45         return self.row, self.col
#      46
#      47     @property
#
# KeyboardInterrupt:

# %%
val, vec = np.linalg.eig(U)
min_ind = list(val).index(min(val))
print(val)
# Out:
# [-7.07106780e-01-7.07106780e-01j  7.07106780e-01-7.07106780e-01j
#   1.00000000e+00-3.22879186e-16j  7.07106780e-01+7.07106780e-01j
#   7.07106780e-01+7.07106820e-01j -7.07106780e-01-7.07106780e-01j
#  -7.07106820e-01+7.07106780e-01j -1.00000000e+00+5.00861695e-16j
#  -1.00000000e+00+2.28508431e-17j  3.31547991e-16+1.00000000e+00j
#  -1.23815888e-16+1.00000000e+00j -7.07106780e-01+7.07106780e-01j
#  -7.07106780e-01+7.07106780e-01j -1.00000000e+00-3.67790872e-16j
#   9.71445147e-17+1.00000000e+00j  2.18575158e-16+1.00000000e+00j]
